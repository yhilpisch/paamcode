# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">

# %% [markdown]
# # Python & AI in Asset Management
# ## Appendix G · Repository and Colab Guide
#
# &copy; Dr. Yves J. Hilpisch<br>
# AI-Powered by GPT 5.1<br>
# The Python Quants GmbH | https://tpq.io<br>
# https://hilpisch.com | https://linktr.ee/dyjh

# %% [markdown]
# ## Notebook Goals
#
# This notebook provides a Colab-friendly bootstrap: checking the environment,
# inspecting the repo layout, and showing how to mount external storage.

# %% [markdown]
# ### Getting Help
#
# - Appendix G explains the rationale and extra tips.
# - Chapter 3 covers project layout in more detail.

# %%
import os
import sys
from pathlib import Path

print('Python', sys.version)
print('CWD   ', os.getcwd())

# %% [markdown]
# ## 1. Inspect Repository Layout
#
# We list top-level folders so you can orient yourself when opening the project in Colab.

# %%
root = Path('..').resolve()
for path in sorted(root.iterdir()):
    if path.name.startswith('.'):
        continue
    print(path)

# %% [markdown]
# ## 2. Data Availability Check
#
# We confirm that the main price file is reachable from this environment.

# %%
data_path = Path('../data/pyaiam_eod.csv')
print('Data exists:', data_path.exists(), '->', data_path)

# %% [markdown]
# ## 3. Exercises
#
# 1. Add cells that mount Google Drive in Colab (if available).
# 2. Write a helper that downloads the data file from a URL if it is missing.
# 3. Print Python, pandas, and NumPy versions in a single summary line.

# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">
