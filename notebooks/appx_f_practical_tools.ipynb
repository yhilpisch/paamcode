# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">

# %% [markdown]
# # Python & AI in Asset Management
# ## Appendix F · Practical Tools
#
# &copy; Dr. Yves J. Hilpisch<br>
# AI-Powered by GPT 5.1<br>
# The Python Quants GmbH | https://tpq.io<br>
# https://hilpisch.com | https://linktr.ee/dyjh

# %% [markdown]
# ## Notebook Goals
#
# This notebook turns Appendix F into practical utilities: configuration
# handling, logging, and simple timer decorators.

# %% [markdown]
# ### Getting Help
#
# - Appendix F describes the philosophy behind these patterns.
# - Chapter 18 shows them inside a full pipeline.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

plt.style.use("seaborn-v0_8")
plt.rcParams.update({"font.family": "serif", "figure.dpi": 300})

DATA_PATH = Path("../data/pyaiam_eod.csv")
if not DATA_PATH.exists():
    DATA_PATH = "https://hilpisch.com/pyaiam_eod.csv"

import logging
import time

# %% [markdown]
# ## 1. Configuration Dictionary
#
# We centralize a few file paths and knobs in one dict.

# %%
CONFIG = {
    'data_file': DATA_PATH,
    'reports_dir': Path('../reports'),
    'feature_window': 20,
}
CONFIG

# %% [markdown]
# ## 2. Logger Helper
#
# A small wrapper sets up structured logging for other notebooks.

# %%
def make_logger(name: str = 'pyaiam') -> logging.Logger:
    logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')
    return logging.getLogger(name)

logger = make_logger()
logger.info('Logger initialized')

# %% [markdown]
# ## 3. Simple Timer Decorator
#
# We measure runtime of functions without sprinkling time.time() everywhere.

# %%
def timed(func):
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        elapsed = time.perf_counter() - start
        logger.info('Function %s took %.3fs', func.__name__, elapsed)
        return result
    return wrapper

@timed
def demo_sleep():
    time.sleep(0.1)

_ = demo_sleep()

# %% [markdown]
# ## 4. Exercises
#
# 1. Extend CONFIG with experiment tags and run modes.
# 2. Add log-to-file capability to make_logger.
# 3. Create a context-manager version of the timer that works with 'with' blocks.

# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">
